# %% [markdown]
# # Import Libararies:-

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %% [markdown]
# # Importing ProfileReport fro statistical analysis:

# %%
from ydata_profiling import ProfileReport

# %% [markdown]
# # Load the Dataset

# %%
df=pd.read_csv('FitBit data.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# df.profile_report()

# %% [markdown]
# # To check the Datatypes

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %% [markdown]
# # To check the Dimension

# %%
df.ndim
# Out:
# 2

# %%
df['ActivityDate'].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
# ActivityDate:categorical data to we need to convert it to numeric
df['Date'] = pd.DatetimeIndex(df['ActivityDate'])

# %%
df['Day'] = pd.DatetimeIndex(df['ActivityDate']).day

# %%
df['Year'] = pd.DatetimeIndex(df['ActivityDate']).year

# %%
df['Month'] = pd.DatetimeIndex(df['ActivityDate']).month

# %%
df[['ActivityDate','Day','Month','Year']]
# Out:
#     ActivityDate  Day  Month  Year
# 0      3/25/2016   25      3  2016
# 1      3/26/2016   26      3  2016
# 2      3/27/2016   27      3  2016
# 3      3/28/2016   28      3  2016
# 4      3/29/2016   29      3  2016
# ..           ...  ...    ...   ...
# 452     4/8/2016    8      4  2016
# 453     4/9/2016    9      4  2016
# 454    4/10/2016   10      4  2016
# 455    4/11/2016   11      4  2016
# 456    4/12/2016   12      4  2016
#
# [457 rows x 4 columns]

# %% [markdown]
# # Date :datetime64[ns]
# # created new column storing the activity date in datetime format

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                        object
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# Date                        datetime64[ns]
# Day                                  int32
# Year                                 int32
# Month                                int32
# dtype: object

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# drop activity date column
df.drop(['ActivityDate'],axis=1)
# KeyError: "['Activity Date'] not found in axis" by default axis=0 which is for row and "activity Date" is a columnso axis=1
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.boxplot(x='Day',y='Calories',data=df)
plt.show()

# %%
df['date_time']=pd.to_datetime(df['ActivityDate'])
df['day_name']=df['date_time'].dt.day_name()

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Date', 'Day',
#        'Year', 'Month', 'date_time', 'day_name'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                        object
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# Date                        datetime64[ns]
# Day                                  int32
# Year                                 int32
# Month                                int32
# date_time                   datetime64[ns]
# day_name                            object
# dtype: object

# %%
sns.scatterplot(x='Calories',y='TotalSteps',data=df)
# Out:
# <Axes: xlabel='Calories', ylabel='TotalSteps'>

# %%
df.drop(columns=['LoggedActivitiesDistance','SedentaryActiveDistance','ModeratelyActiveDistance','Id'],inplace=True)

# %%
df
# Out:
#     ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0      3/25/2016       11004       7.110000         7.110000
# 1      3/26/2016       17609      11.550000        11.550000
# 2      3/27/2016       12736       8.530000         8.530000
# 3      3/28/2016       13231       8.930000         8.930000
# 4      3/29/2016       12041       7.850000         7.850000
# ..           ...         ...            ...              ...
# 452     4/8/2016       23014      20.389999        20.389999
# 453     4/9/2016       16470       8.070000         8.070000
# 454    4/10/2016       28497      27.530001        27.530001
# 455    4/11/2016       10622       8.060000         8.060000
# 456    4/12/2016        2350       1.780000         1.780000
#
#      VeryActiveDistance  LightActiveDistance  VeryActiveMinutes  \
# 0                  2.57                 4.07                 33
# 1                  6.92                 3.91                 89
# ...

# %%
x=df[['TotalSteps','TotalDistance','TrackerDistance','VeryActiveDistance','LightActiveDistance','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']]

# %%
y=df["Calories"]

# %%
x
# Out:
#      TotalSteps  TotalDistance  TrackerDistance  VeryActiveDistance  \
# 0         11004       7.110000         7.110000                2.57
# 1         17609      11.550000        11.550000                6.92
# 2         12736       8.530000         8.530000                4.66
# 3         13231       8.930000         8.930000                3.19
# 4         12041       7.850000         7.850000                2.16
# ..          ...            ...              ...                 ...
# 452       23014      20.389999        20.389999               11.10
# 453       16470       8.070000         8.070000                0.00
# 454       28497      27.530001        27.530001               21.92
# 455       10622       8.060000         8.060000                1.47
# 456        2350       1.780000         1.780000                0.00
#
#      LightActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# 0                   4.07                 33                   12
# ...

# %%
y
# Out:
# 0      1819
# 1      2154
# 2      1944
# 3      1932
# 4      1886
#        ...
# 452    4196
# 453    3841
# 454    4526
# 455    2820
# 456     938
# Name: Calories, Length: 457, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)

# Make predictions
Y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 178111.07967984767
# R-squared: 0.720471951141427

# %%
print(model.intercept_)
# Out:
# 643.0139783833231

# %%
print(model.coef_)
# Out:
# [-4.71741799e-01  6.87231360e+02  1.68334034e+02 -4.57790118e+02
#  -1.43949508e+02  2.58898754e+01  4.16433291e+00  2.32976511e+00
#   7.36990170e-01]

# %%
df
# Out:
#     ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0      3/25/2016       11004       7.110000         7.110000
# 1      3/26/2016       17609      11.550000        11.550000
# 2      3/27/2016       12736       8.530000         8.530000
# 3      3/28/2016       13231       8.930000         8.930000
# 4      3/29/2016       12041       7.850000         7.850000
# ..           ...         ...            ...              ...
# 452     4/8/2016       23014      20.389999        20.389999
# 453     4/9/2016       16470       8.070000         8.070000
# 454    4/10/2016       28497      27.530001        27.530001
# 455    4/11/2016       10622       8.060000         8.060000
# 456    4/12/2016        2350       1.780000         1.780000
#
#      VeryActiveDistance  LightActiveDistance  VeryActiveMinutes  \
# 0                  2.57                 4.07                 33
# 1                  6.92                 3.91                 89
# ...

# %%
print(model.predict([[11004,7.110000,7.110000,2.57,4.07,33,12,205,804]]))
# Out:
# [1747.12190079]
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
